# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re

# %%
# Load datasets
jobs = pd.read_csv('jobs.csv')
applicants = pd.read_csv('applicants.csv')

# %%
# Function to clean text data
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\W', ' ', text)  # Remove non-word characters
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text

# Preprocess job descriptions and requirements
jobs['combined_text'] = jobs['description'] + ' ' + jobs['requirements']
jobs['combined_text'] = jobs['combined_text'].apply(clean_text)

# Preprocess applicant skills
applicants['cleaned_skills'] = applicants['skills'].apply(clean_text)

# %%
# Create TF-IDF vectors for job descriptions and applicant skills
vectorizer = TfidfVectorizer()
job_vectors = vectorizer.fit_transform(jobs['combined_text'])
applicant_vectors = vectorizer.transform(applicants['cleaned_skills'])

# %%
# Calculate cosine similarities between applicants and jobs
cosine_similarities = cosine_similarity(applicant_vectors, job_vectors)

# %%
# Function to get top N job recommendations for a given applicant
def get_recommendations(applicant_index, top_n=5):
    similar_jobs = cosine_similarities[applicant_index]
    similar_jobs_indices = similar_jobs.argsort()[-top_n:][::-1]
    return jobs.iloc[similar_jobs_indices]

# Get and print top 5 job recommendations for each applicant
for index, applicant in applicants.iterrows():
    recommendations = get_recommendations(index, top_n=5)
    print(f"Rekomendasi untuk pelamar {applicant['name']}:")
    print(recommendations[['title', 'description', 'requirements']])
    print('\n' + '='*80 + '\n')
# Out:
# Rekomendasi untuk pelamar Alice Johnson:
#                   title                                        description  \
# 2           UX Designer  Design user experiences with a focus on access...
# 0        Data Scientist  Develop data models and algorithms for predict...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 1    Frontend Developer  Create interactive and responsive front-end in...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
#
#                                         requirements
# 2            UX Design, Adobe XD, Figma, Prototyping
# 0                   Python, R, SQL, Machine Learning
# 8      SEO, Google Analytics, HTML, Keyword Research
# 1                       JavaScript, React, CSS, HTML
# 4  Digital Marketing, SEO, Content Strategy, Goog...
#
# ================================================================================
#
# Rekomendasi untuk pelamar Bob Smith:
#                        title  \
# 9           Graphic Designer
# 0             Data Scientist
# 5  Machine Learning Engineer
# 2                UX Designer
# 3           Business Analyst
#
#                                          description  \
# 9  Design visually appealing graphics and brandin...
# 0  Develop data models and algorithms for predict...
# 5  Build and deploy machine learning models and s...
# 2  Design user experiences with a focus on access...
# 3  Analyze business processes and requirements to...
#
#                                         requirements
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 0                   Python, R, SQL, Machine Learning
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 2            UX Design, Adobe XD, Figma, Prototyping
# 3  Business Analysis, Excel, SQL, Project Management
#
# ================================================================================
#
# Rekomendasi untuk pelamar Carol White:
#                   title                                        description  \
# 7  Full Stack Developer  Develop both front-end and back-end components...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 6       Product Manager  Oversee product development and coordinate wit...
# 1    Frontend Developer  Create interactive and responsive front-end in...
# 8        SEO Specialist  Optimize website content and structure for sea...
#
#                                         requirements
# 7           JavaScript, Node.js, SQL, Cloud Services
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 6    Product Management, Agile, Scrum, Communication
# 1                       JavaScript, React, CSS, HTML
# 8      SEO, Google Analytics, HTML, Keyword Research
#
# ================================================================================
#
# Rekomendasi untuk pelamar Dave Brown:
#                        title  \
# 3           Business Analyst
# 5  Machine Learning Engineer
# 8             SEO Specialist
# 4       Marketing Specialist
# 9           Graphic Designer
#
#                                          description  \
# 3  Analyze business processes and requirements to...
# 5  Build and deploy machine learning models and s...
# 8  Optimize website content and structure for sea...
# 4  Implement and manage marketing campaigns acros...
# 9  Design visually appealing graphics and brandin...
#
#                                         requirements
# 3  Business Analysis, Excel, SQL, Project Management
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 8      SEO, Google Analytics, HTML, Keyword Research
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
#
# ================================================================================
#
# Rekomendasi untuk pelamar Eve Davis:
#                        title  \
# 6            Product Manager
# 0             Data Scientist
# 5  Machine Learning Engineer
# 9           Graphic Designer
# 8             SEO Specialist
#
#                                          description  \
# 6  Oversee product development and coordinate wit...
# 0  Develop data models and algorithms for predict...
# 5  Build and deploy machine learning models and s...
# 9  Design visually appealing graphics and brandin...
# 8  Optimize website content and structure for sea...
#
#                                         requirements
# 6    Product Management, Agile, Scrum, Communication
# 0                   Python, R, SQL, Machine Learning
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 8      SEO, Google Analytics, HTML, Keyword Research
#
# ================================================================================
#
# Rekomendasi untuk pelamar Frank Harris:
#                        title  \
# 0             Data Scientist
# 5  Machine Learning Engineer
# 6            Product Manager
# 9           Graphic Designer
# 8             SEO Specialist
#
#                                          description  \
# 0  Develop data models and algorithms for predict...
# 5  Build and deploy machine learning models and s...
# 6  Oversee product development and coordinate wit...
# 9  Design visually appealing graphics and brandin...
# 8  Optimize website content and structure for sea...
#
#                                         requirements
# 0                   Python, R, SQL, Machine Learning
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 6    Product Management, Agile, Scrum, Communication
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 8      SEO, Google Analytics, HTML, Keyword Research
#
# ================================================================================
#
# Rekomendasi untuk pelamar Grace Lee:
#                        title  \
# 6            Product Manager
# 3           Business Analyst
# 0             Data Scientist
# 5  Machine Learning Engineer
# 7       Full Stack Developer
#
#                                          description  \
# 6  Oversee product development and coordinate wit...
# 3  Analyze business processes and requirements to...
# 0  Develop data models and algorithms for predict...
# 5  Build and deploy machine learning models and s...
# 7  Develop both front-end and back-end components...
#
#                                         requirements
# 6    Product Management, Agile, Scrum, Communication
# 3  Business Analysis, Excel, SQL, Project Management
# 0                   Python, R, SQL, Machine Learning
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 7           JavaScript, Node.js, SQL, Cloud Services
#
# ================================================================================
#
# Rekomendasi untuk pelamar Henry Wilson:
#                        title  \
# 0             Data Scientist
# 1         Frontend Developer
# 5  Machine Learning Engineer
# 8             SEO Specialist
# 9           Graphic Designer
#
#                                          description  \
# 0  Develop data models and algorithms for predict...
# 1  Create interactive and responsive front-end in...
# 5  Build and deploy machine learning models and s...
# 8  Optimize website content and structure for sea...
# 9  Design visually appealing graphics and brandin...
#
#                                         requirements
# 0                   Python, R, SQL, Machine Learning
# 1                       JavaScript, React, CSS, HTML
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 8      SEO, Google Analytics, HTML, Keyword Research
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
#
# ================================================================================
#
# Rekomendasi untuk pelamar Irene Walker:
#                   title                                        description  \
# 3      Business Analyst  Analyze business processes and requirements to...
# 7  Full Stack Developer  Develop both front-end and back-end components...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 9      Graphic Designer  Design visually appealing graphics and brandin...
#
#                                         requirements
# 3  Business Analysis, Excel, SQL, Project Management
# 7           JavaScript, Node.js, SQL, Cloud Services
# 8      SEO, Google Analytics, HTML, Keyword Research
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
#
# ================================================================================
#
# Rekomendasi untuk pelamar Jack Turner:
#                   title                                        description  \
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 7  Full Stack Developer  Develop both front-end and back-end components...
# 6       Product Manager  Oversee product development and coordinate wit...
#
#                                         requirements
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 8      SEO, Google Analytics, HTML, Keyword Research
# 7           JavaScript, Node.js, SQL, Cloud Services
# 6    Product Management, Agile, Scrum, Communication
#
# ================================================================================
#
# Rekomendasi untuk pelamar Karen Adams:
#                   title                                        description  \
# 2           UX Designer  Design user experiences with a focus on access...
# 3      Business Analyst  Analyze business processes and requirements to...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 1    Frontend Developer  Create interactive and responsive front-end in...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
#
#                                         requirements
# 2            UX Design, Adobe XD, Figma, Prototyping
# 3  Business Analysis, Excel, SQL, Project Management
# 8      SEO, Google Analytics, HTML, Keyword Research
# 1                       JavaScript, React, CSS, HTML
# 4  Digital Marketing, SEO, Content Strategy, Goog...
#
# ================================================================================
#
# Rekomendasi untuk pelamar Liam Martinez:
#                   title                                        description  \
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 2           UX Designer  Design user experiences with a focus on access...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 6       Product Manager  Oversee product development and coordinate wit...
#
#                                         requirements
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 8      SEO, Google Analytics, HTML, Keyword Research
# 2            UX Design, Adobe XD, Figma, Prototyping
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 6    Product Management, Agile, Scrum, Communication
#
# ================================================================================
#
# Rekomendasi untuk pelamar Mia Rodriguez:
#                        title  \
# 8             SEO Specialist
# 6            Product Manager
# 0             Data Scientist
# 5  Machine Learning Engineer
# 9           Graphic Designer
#
#                                          description  \
# 8  Optimize website content and structure for sea...
# 6  Oversee product development and coordinate wit...
# 0  Develop data models and algorithms for predict...
# 5  Build and deploy machine learning models and s...
# 9  Design visually appealing graphics and brandin...
#
#                                         requirements
# 8      SEO, Google Analytics, HTML, Keyword Research
# 6    Product Management, Agile, Scrum, Communication
# 0                   Python, R, SQL, Machine Learning
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
#
# ================================================================================
#
# Rekomendasi untuk pelamar Noah King:
#                   title                                        description  \
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 6       Product Manager  Oversee product development and coordinate wit...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 7  Full Stack Developer  Develop both front-end and back-end components...
#
#                                         requirements
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 6    Product Management, Agile, Scrum, Communication
# 8      SEO, Google Analytics, HTML, Keyword Research
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 7           JavaScript, Node.js, SQL, Cloud Services
#
# ================================================================================
#
# Rekomendasi untuk pelamar Olivia Scott:
#                   title                                        description  \
# 3      Business Analyst  Analyze business processes and requirements to...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 0        Data Scientist  Develop data models and algorithms for predict...
# 7  Full Stack Developer  Develop both front-end and back-end components...
# 8        SEO Specialist  Optimize website content and structure for sea...
#
#                                         requirements
# 3  Business Analysis, Excel, SQL, Project Management
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 0                   Python, R, SQL, Machine Learning
# 7           JavaScript, Node.js, SQL, Cloud Services
# 8      SEO, Google Analytics, HTML, Keyword Research
#
# ================================================================================
#
# Rekomendasi untuk pelamar Peter Evans:
#                   title                                        description  \
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 3      Business Analyst  Analyze business processes and requirements to...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 6       Product Manager  Oversee product development and coordinate wit...
#
#                                         requirements
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 3  Business Analysis, Excel, SQL, Project Management
# 8      SEO, Google Analytics, HTML, Keyword Research
# 6    Product Management, Agile, Scrum, Communication
#
# ================================================================================
#
# Rekomendasi untuk pelamar Quinn Baker:
#                   title                                        description  \
# 8        SEO Specialist  Optimize website content and structure for sea...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 7  Full Stack Developer  Develop both front-end and back-end components...
# 6       Product Manager  Oversee product development and coordinate wit...
#
#                                         requirements
# 8      SEO, Google Analytics, HTML, Keyword Research
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 7           JavaScript, Node.js, SQL, Cloud Services
# 6    Product Management, Agile, Scrum, Communication
#
# ================================================================================
#
# Rekomendasi untuk pelamar Ruby Gonzalez:
#                   title                                        description  \
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
# 3      Business Analyst  Analyze business processes and requirements to...
# 7  Full Stack Developer  Develop both front-end and back-end components...
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 8        SEO Specialist  Optimize website content and structure for sea...
#
#                                         requirements
# 4  Digital Marketing, SEO, Content Strategy, Goog...
# 3  Business Analysis, Excel, SQL, Project Management
# 7           JavaScript, Node.js, SQL, Cloud Services
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 8      SEO, Google Analytics, HTML, Keyword Research
#
# ================================================================================
#
# Rekomendasi untuk pelamar Steve Wright:
#                        title  \
# 7       Full Stack Developer
# 0             Data Scientist
# 5  Machine Learning Engineer
# 9           Graphic Designer
# 8             SEO Specialist
#
#                                          description  \
# 7  Develop both front-end and back-end components...
# 0  Develop data models and algorithms for predict...
# 5  Build and deploy machine learning models and s...
# 9  Design visually appealing graphics and brandin...
# 8  Optimize website content and structure for sea...
#
#                                         requirements
# 7           JavaScript, Node.js, SQL, Cloud Services
# 0                   Python, R, SQL, Machine Learning
# 5    Python, TensorFlow, Scikit-learn, Data Analysis
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 8      SEO, Google Analytics, HTML, Keyword Research
#
# ================================================================================
#
# Rekomendasi untuk pelamar Tina Harris:
#                   title                                        description  \
# 9      Graphic Designer  Design visually appealing graphics and brandin...
# 0        Data Scientist  Develop data models and algorithms for predict...
# 8        SEO Specialist  Optimize website content and structure for sea...
# 1    Frontend Developer  Create interactive and responsive front-end in...
# 4  Marketing Specialist  Implement and manage marketing campaigns acros...
#
#                                         requirements
# 9  Adobe Photoshop, Illustrator, Branding, Creati...
# 0                   Python, R, SQL, Machine Learning
# 8      SEO, Google Analytics, HTML, Keyword Research
# 1                       JavaScript, React, CSS, HTML
# 4  Digital Marketing, SEO, Content Strategy, Goog...
#
# ================================================================================
